# %% [markdown]
# Analyzing Zomato data using Python

# %% [markdown]
# Task1: Compare the online and offline delivery of the restaurants- Which one is higher?
# Task2: What types of restaurants are most popular with the general public?
# Task3: What price range do couples prefer when dining out at restaurants?

# %% [markdown]
# Tthe required libraries are imported.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The data is read into a dataframe

# %%
df = pd.read_csv('Zomato data .csv')
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
sns.countplot(x = df['online_order'])
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
sns.countplot(x = df['listed_in(type)'])
plt.xlabel('different type of restaurants')
plt.grid('True')
